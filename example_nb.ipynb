# %%
from env import RubiksCubeEnv

# %%
myenv = RubiksCubeEnv(scramble_moves=1)

# %%
myenv.reset()
# Out:
# (array([0, 0, 5, 0, 0, 5, 0, 0, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 0, 4,
#         4, 0, 4, 4, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 5, 5, 1, 5, 5, 1, 5,
#         5, 1, 1, 4, 1, 1, 4, 1, 1, 4]),
#  {})

# %%
myenv.render()

# %%
myenv.reset()
curr, reward, done, _ = myenv.step(0)
print("Reward :",reward)
myenv.render()
curr, reward, done, _ = myenv.step(1)
print("Reward :",reward)
myenv.render()
curr, reward, done, _ = myenv.step(2)
print("Reward :",reward)
myenv.render()
# Out:
# Reward : -1.9518518518518524
# Reward : -1.5814814814814815
# Reward : -0.6555555555555552

# %%
curr, reward, done, _ = myenv.step(8)
print("Reward :",reward)
myenv.render()
curr, reward, done, _ = myenv.step(7)
print("Reward :",reward)
myenv.render()
curr, reward, done, _ = myenv.step(6)
print("Reward :",reward)
myenv.render()
# Out:
# Reward : 0.08518518518518545
# Reward : 1.5666666666666662
# Reward : 1.7518518518518522
